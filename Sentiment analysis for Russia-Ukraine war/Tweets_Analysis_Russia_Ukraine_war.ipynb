# %%
import pandas as pd
data=pd.read_csv("/content/Ukraine_war.csv",engine='python', encoding='latin-1', error_bad_lines=False)

data.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Skipping line 742: unexpected end of data
# Skipping line 365: Expected 29 fields in line 365, saw 49
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/ksenijapavlovic/status/150...
# 1  https://twitter.com/ty_phoon31/status/15002598...
# 2  https://twitter.com/ann_peace22/status/1500259...
# 3  https://twitter.com/GardensR4Health/status/150...
# 4  https://twitter.com/kbrunolieber/status/150025...
#
#                         date  \
# 0  2022-03-05 23:59:58+00:00
# 1  2022-03-05 23:59:58+00:00
# 2  2022-03-05 23:59:54+00:00
# 3  2022-03-05 23:59:52+00:00
# 4  2022-03-05 23:59:52+00:00
#
#                                              content  \
# 0  There was an anti war protest for #Ukraine as ...
# 1  https://t.co/Z1pURKlNHu NATO followed USA into...
# 2  @mfa_russia @RusEmbUSA @RussiaUN @MFA_Ukraine ...
# 3  @nytimes This war could have been avoided by e...
# 4  @ggreenwald Remember the biggest mistake made ...
#
#                                      renderedContent                   id  \
# 0  There was an anti war protest for #Ukraine as ...  1500259859937337349
# 1  abc.net.au/news/2022-03-0â¦ NATO followed USA...  1500259857160568834
# 2  @mfa_russia @RusEmbUSA @RussiaUN @MFA_Ukraine ...  1500259841520111616
# 3  @nytimes This war could have been avoided by e...  1500259833915883525
# 4  @ggreenwald Remember the biggest mistake made ...  1500259832649203713
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  retweetedTweet  \
# 0             4         25  ...             NaN
# 1             0          0  ...             NaN
# 2             0          0  ...             NaN
# 3             0          0  ...             NaN
# 4             0          2  ...             NaN
#
#                                          quotedTweet inReplyToTweetId  \
# 0  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 1                                                NaN              NaN
# 2                                                NaN     1.500182e+18
# 3                                                NaN     1.499516e+18
# 4                                                NaN     1.500200e+18
#
#                                        inReplyToUser  \
# 0                                                NaN
# 1                                                NaN
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                       mentionedUsers coordinates place  \
# 0                                                NaN         NaN   NaN
# 1                                                NaN         NaN   NaN
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
#
#                 hashtags cashtags        Searh
# 0            ['Ukraine']      NaN  Ukraine war
# 1                    NaN      NaN  Ukraine war
# 2  ['IStandWithUkraine']      NaN  Ukraine war
# 3                    NaN      NaN  Ukraine war
# 4                    NaN      NaN  Ukraine war
#
# [5 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _type             739 non-null    object
#  1   url               739 non-null    object
#  2   date              739 non-null    object
#  3   content           739 non-null    object
#  4   renderedContent   739 non-null    object
#  5   id                739 non-null    int64
#  6   user              739 non-null    object
#  7   replyCount        739 non-null    int64
#  8   retweetCount      739 non-null    int64
#  9   likeCount         739 non-null    int64
#  10  quoteCount        739 non-null    int64
#  11  conversationId    739 non-null    int64
#  12  lang              739 non-null    object
#  13  source            739 non-null    object
#  14  sourceUrl         739 non-null    object
#  15  sourceLabel       739 non-null    object
#  16  outlinks          275 non-null    object
#  17  tcooutlinks       275 non-null    object
#  18  media             82 non-null     object
#  19  retweetedTweet    0 non-null      float64
#  20  quotedTweet       66 non-null     object
#  21  inReplyToTweetId  314 non-null    float64
#  22  inReplyToUser     314 non-null    object
#  23  mentionedUsers    377 non-null    object
#  24  coordinates       11 non-null     object
#  25  place             11 non-null     object
#  26  hashtags          198 non-null    object
#  27  cashtags          1 non-null      object
#  28  Searh             739 non-null    object
# dtypes: float64(2), int64(6), object(21)
# memory usage: 167.6+ KB

# %%
data.describe()
# Out:
#                  id  replyCount  retweetCount    likeCount  quoteCount  \
# count  7.390000e+02  739.000000    739.000000   739.000000  739.000000
# mean   1.500255e+18    1.552097      2.979702    12.732070    0.389716
# std    3.947420e+12   12.314463     21.610581   109.666425    3.604379
# min    1.500251e+18    0.000000      0.000000     0.000000    0.000000
# 25%    1.500251e+18    0.000000      0.000000     0.000000    0.000000
# 50%    1.500252e+18    0.000000      0.000000     0.000000    0.000000
# 75%    1.500259e+18    1.000000      0.000000     1.000000    0.000000
# max    1.500260e+18  219.000000    332.000000  2337.000000   68.000000
#
#        conversationId  retweetedTweet  inReplyToTweetId
# count    7.390000e+02             0.0      3.140000e+02
# mean     1.500106e+18             NaN      1.500107e+18
# std      9.838873e+14             NaN      4.829082e+14
# min      1.478470e+18             NaN      1.495760e+18
# 25%      1.500216e+18             NaN      1.500155e+18
# 50%      1.500251e+18             NaN      1.500231e+18
# 75%      1.500258e+18             NaN      1.500250e+18
# max      1.500260e+18             NaN      1.500260e+18

# %%
data.isnull().sum()
# Out:
# _type                 0
# url                   0
# date                  0
# content               0
# renderedContent       0
# id                    0
# user                  0
# replyCount            0
# retweetCount          0
# likeCount             0
# quoteCount            0
# conversationId        0
# lang                  0
# source                0
# sourceUrl             0
# sourceLabel           0
# outlinks            464
# tcooutlinks         464
# media               657
# retweetedTweet      739
# quotedTweet         673
# inReplyToTweetId    425
# inReplyToUser       425
# mentionedUsers      362
# coordinates         728
# place               728
# hashtags            541
# cashtags            738
# Searh                 0
# dtype: int64

# %%
col=list(data.columns)
col
# Out:
# ['_type',
#  'url',
#  'date',
#  'content',
#  'renderedContent',
#  'id',
#  'user',
#  'replyCount',
#  'retweetCount',
#  'likeCount',
#  'quoteCount',
#  'conversationId',
#  'lang',
#  'source',
#  'sourceUrl',
#  'sourceLabel',
#  'outlinks',
#  'tcooutlinks',
#  'media',
#  'retweetedTweet',
#  'quotedTweet',
#  'inReplyToTweetId',
#  'inReplyToUser',
#  'mentionedUsers',
#  'coordinates',
#  'place',
#  'hashtags',
#  'cashtags',
#  'Searh']

# %%
data['content']
# Out:
# 0      There was an anti war protest for #Ukraine as ...
# 1      https://t.co/Z1pURKlNHu NATO followed USA into...
# 2      @mfa_russia @RusEmbUSA @RussiaUN @MFA_Ukraine ...
# 3      @nytimes This war could have been avoided by e...
# 4      @ggreenwald Remember the biggest mistake made ...
#                              ...
# 734    What the War in Ukraine Means for the Worldâ...
# 735    @escapeartistes Hmmm havenât seen those. But...
# 736    I fully expect NATO leaders and the Ukraine mi...
# 737    @NewGuyUserName1 @NovElection2024 He does when...
# 738    Russia VS Ukraine War. It's horrible. I made a...
# Name: content, Length: 739, dtype: object

# %%
data['lang'].value_counts()
# Out:
# en     719
# und      7
# de       5
# fr       3
# hi       2
# in       2
# ja       1
# Name: lang, dtype: int64

# %%
data.lang.value_counts().sort_values().plot(kind='pie')

# %%
text=data['content'][100]
text
# Out:
# '1) go to maps\n\n2) find a Russian city (like Moscow)\n\n3) find a restaurant, cafe or bar\n\n4) write a review but write about the war in #Ukraine \n\n5) post it\n\n#StandWithUkraineï¸\x8f #StopPutin #SlavaUkraini #UkraineRussiaWar #Russia #UkraineUnderAttaÑ\x81k #FBPE https://t.co/TEkreF6Q0a'

# %% [markdown]
# as we can see, there is a lot of hashtags , so let's work on it

# %%
import re
import nltk

# %%
htg=re.findall(r"#(\w+)",text)
htg
# Out:
# ['Ukraine',
#  'StandWithUkraineï',
#  'StopPutin',
#  'SlavaUkraini',
#  'UkraineRussiaWar',
#  'Russia',
#  'UkraineUnderAttaÑ',
#  'FBPE']

# %%
def hashtag_extract(text_corpus):
  hashtag=[]
  for text in text_corpus:
    ht=re.findall(r"#(\w+)",str(text))
    hashtag.append(ht)

  return hashtag

# %%
def hashtag_freq(hashtag):
  a=nltk.FreqDist(hashtag)
  d=pd.DataFrame({'Hashtag':list(a.keys()),
                 'Freq': list(a.values())}
                 )
  d=d.nlargest(columns="Freq",n=30)

  return d

# %%
hashtags=hashtag_extract(data['content'])
hashtags
# Out:
# [['Ukraine'],
#  [],
#  ['IStandWithUkraine'],
#  [],
#  [],
#  [],
#  ['sanctions', 'russia', 'WW3', 'Ukraine', 'NATO', 'USA', 'war', 'Politics'],
#  ['Russia', 'UkraineWar'],
#  [],
#  ['UkraineRussianWar', 'Ukraine', 'Russia', 'CzarVladimir'],
#  [],
#  ['Ukraine', 'StanGrant', 'Dutton', 'insiders', 'auspol'],
#  [],
#  [],
#  [],
#  [],
#  ['UkraineRussianWar', 'Russia'],
#  [],
#  [],
#  [],
#  ['UKRAINE'],
#  ['Russia', 'WWWIII'],
#  [],
#  [],
#  ['TruckersConvoy2022', 'PutinWarCrimes', 'StopRussia', 'DemVoice1'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine',
#   'NoWar',
#   'Stop_the_War',
#   'We_are_all_friends',
#   'Wake_up_troops',
#   'Hugs_to_all'],
#  [],
#  [],
#  [],
#  [],
#  ['ukraine'],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['UkraineRussianWar',
#   'IStandWithUkraine',
#   'worldwar3',
#   'AzovBattalion',
#   'russia',
#   'ukraine',
#   'IStandWithPutin',
#   'NoFlyZoneOverUkraine',
#   'RussianArmy'],
#  ['StopEnablingPutin'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Putin', 'war', 'WarCrimes', 'ukraine', 'StandWithUkrain', 'russia', 'NYC'],
#  [],
#  [],
#  [],
#  [],
#  ['UkraineRussianWar', 'UkraineWar'],
#  ['cnn', 'Ukraine'],
#  ['Russia', 'Ukraine'],
#  [],
#  [],
#  [],
#  ['RussiaUkraineConflict', 'Ukraine', 'Russia'],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['US',
#   'Iraq',
#   'Ukraine',
#   'Lybia',
#   'Syria',
#   'Afghanistan',
#   'Palestine',
#   'RussianUkrainianWar'],
#  ['Ukraine',
#   'StandWithUkraineï',
#   'StopPutin',
#   'SlavaUkraini',
#   'UkraineRussiaWar',
#   'Russia',
#   'UkraineUnderAttaÑ',
#   'FBPE'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['MiddleEast', 'UkraineRussianWar', 'CrudeOil'],
#  [],
#  ['BREAKING', 'Ukraine'],
#  [],
#  [],
#  ['ClosetheSkyoverUkraine', 'NoFlyZone', 'NoFlyZoneOverUkraine'],
#  [],
#  ['RussiaEU'],
#  ['Ukraine', 'Russia'],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Godspeed'],
#  [],
#  [],
#  [],
#  [],
#  ['Ukrania'],
#  ['putin', 'Ukraine', 'fuckputin', 'PutinWarCriminal'],
#  [],
#  [],
#  ['Ukraine'],
#  ['SlavaUkraini', 'GloryToUkraine', 'UkraineWar', 'SupportUkraine'],
#  [],
#  [],
#  [],
#  [],
#  ['NOBODYWANTSWAR', 'STOPWAR', 'UKRAINEWAR', 'WARINUKRAINE'],
#  [],
#  [],
#  ['PrayingForUkraine', 'Genocide', 'war'],
#  [],
#  ['MaksimChmerkovskiy'],
#  ['Russia', 'Ukraine', 'War', 'USSR'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ukraine', 'russia', 'putin', 'peace', 'war', 'digitalcollage'],
#  [],
#  ['kyiv', 'ukraine', 'war'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Western_media_racism', 'RussianUkrainianWar', 'Ø'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['UkraineUnderAttaÑ', 'ColdWar', 'CIA', 'PutinWarCrimes'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'VladimirPutin', 'Russia'],
#  [],
#  ['RT', 'UkraineCrises', 'RussiaUkraineCrisis'],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'UkraineKrieg', 'UkraineWar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Russia'],
#  [],
#  ['Ukraine'],
#  ['NoFlyZone', 'Ukraine'],
#  ['Putinâ', 'Ukraine'],
#  [],
#  ['Putin',
#   'Russia',
#   'China',
#   'Ukraine',
#   'Russian',
#   'Chinese',
#   'sanctions',
#   'cancel'],
#  ['Ukraine'],
#  [],
#  ['QueMaskOffbyFuture', 'Ukraineonthebrain'],
#  [],
#  [],
#  ['UkraineConflict', 'UkraineWar', 'Ukraine', 'NoWar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Russia'],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['JohnsonTheRussianStooge', 'tory', 'Brexit'],
#  [],
#  [],
#  [],
#  ['UkraineRussianWar', 'RussiaUkraine', 'Ukraine', 'Russia', 'UkraineWar'],
#  [],
#  [],
#  ['Russia', 'Ukraine', 'UkraineRussianWar', 'war'],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  ['Putin', 'sanctions', 'Russia', 'noflyzone', 'Ukraine'],
#  ['Ukraine'],
#  ['Ukraine'],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Russia', 'War', 'WarCrimes', 'WARINUKRAINE', 'Border'],
#  ['Ukraine', 'Russia', 'InvasionUcrania'],
#  ['daytrading', 'stocks', 'stockmarket'],
#  ['Business', 'business'],
#  ['Propaganda',
#   'RussiaUkraineWar',
#   'Russia',
#   'Putin',
#   'Ukraine',
#   'information',
#   'publicity',
#   'war',
#   'propagandawars'],
#  ['Putinâ', 'Ukraine', 'UkraineRussiaWar'],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  ['StandWithUkraine'],
#  [],
#  [],
#  ['stopwar', 'stoprussia', 'ukraine', 'lettherebepeace', 'cancelputin'],
#  ['Ukraine'],
#  [],
#  ['SupportUkraine',
#   'HelpUkraine',
#   'Ukrainians',
#   'Russians',
#   'FreeUkraine',
#   'UkraineWar'],
#  [],
#  [],
#  ['PutinWarCriminal',
#   'PutinWarCrimes',
#   'Putin',
#   'killPutin',
#   'Putitler',
#   'Ukraine',
#   'Russia',
#   'war'],
#  [],
#  [],
#  ['London', 'TrafalgarSquare', 'playforukraine', 'Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  ['RussianUkrainianWar'],
#  [],
#  ['Russia', 'Russia'],
#  [],
#  [],
#  [],
#  [],
#  ['stopwar', 'stoprussia', 'ukraine', 'lettherebepeace', 'cancelputin'],
#  ['ThankYouJournalistsForTheNewsWeGetFromYou', 'AndyVermautThanksYou'],
#  ['news', 'topstories', 'berkleybearnews'],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Russia', 'PutinWarCriminal'],
#  ['Genocide', 'istandwithrussia', 'RussianUkrainianWar'],
#  [],
#  [],
#  [],
#  ['Putin', 'Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['NoFlyZoneOverUkraine'],
#  [],
#  [],
#  ['Putin', 'Ukraine'],
#  ['stopwar', 'stoprussia', 'ukraine', 'lettherebepeace', 'cancelputin'],
#  ['Ukraine'],
#  ['GOPtheRussianParty'],
#  [],
#  ['Putin', 'Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  ['meidastouch', 'Rubio', 'Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  ['UkraineRussianWar'],
#  ['Russia',
#   'Ukraine',
#   'UkraineArmy',
#   'UkraineConflict',
#   'UkraineWar',
#   'UkraineCrisis'],
#  [],
#  ['WARINUKRAINE', 'CloseTheSkyUkraine'],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Washington', 'nytimes', 'nato', 'eu'],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  ['prayforukraine', 'ukraine', 'peaceforukraine', 'NFT'],
#  [],
#  ['Ukraine', 'Biafra', 'Biafra', 'FreeMaziNnamdiKanuNow'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  ['Ukraine',
#   'Russia',
#   'UkraineRussia',
#   'RussiaUkraine',
#   'RussiaUkraineWar',
#   'rusiaukraina',
#   'UkraineRussianWar',
#   'UkraineRussiaWar',
#   'UkraineWar'],
#  [],
#  ['Ukraine', 'Russie', 'Peace', 'war'],
#  [],
#  ['Ukraine', 'Russia', 'Kyiv'],
#  [],
#  [],
#  ['StandWithUkraine'],
#  [],
#  [],
#  [],
#  [],
#  ['BigAg'],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  ['MAGA', 'Trump', 'Republican', 'Jan6th', 'Ukraine'],
#  [],
#  [],
#  ['Russia', 'Ukraine', 'anime', 'movie', 'Russians'],
#  ['Stop'],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Russie', 'war', 'Peace'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ukraine'],
#  ['Ukraine', 'SundayMorning', 'SlavaUkraine'],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  ['Ukraine',
#   'UkraineRussiaWar',
#   'UkraineKrieg',
#   'UkraineUnderAttack',
#   'UkraineWar',
#   'UkraineInvasion',
#   'UkraineRussie',
#   'UkraineRussiaCrisis',
#   'SaveUkraine',
#   'drones',
#   'spying'],
#  ['NATO', 'Putin', 'Ukraine', 'PutinsWar'],
#  [],
#  ['cdnpoli', 'Ukraine', 'PutinWarCrimes', 'putinpuppet', 'Putins'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine',
#   'Russie',
#   'Kharkiv',
#   'UkraineRussianWar',
#   'Poutine',
#   'UkraineWar'],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  ['UkraineRussianWar', 'Ukraine'],
#  ['USA', 'EU', 'UK', 'NATO'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Boycott', 'ukrainewar', 'UkraineRussiaWar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  ['Luhansk', 'Zaporizhzhia', 'Ukraine', 'Russia', 'UkraineWar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Bitcoin',
#   'Ukraine',
#   'Russia',
#   'cryptocurrency',
#   'CryptoCurrencies',
#   'Bitcoin',
#   'Ethereum',
#   'NFT',
#   'NFTs',
#   'NFTCommunity',
#   'OtherEconomy',
#   'OtraEconomia',
#   'Metaverse'],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  ['Lviv', 'Ukraine', 'RussianAggression'],
#  [],
#  [],
#  [],
#  [],
#  ['Economy'],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  ['Putin', 'Ukraine'],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine',
#   'UkraineRussianWar',
#   'UkraineWar',
#   'UkraineUnderAttaÑ',
#   'Ukraine',
#   'UkraineRussia',
#   'Ukraina'],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Stop'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ukrainewar'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  ['AfricansinUkraine',
#   'VOA',
#   'Putin',
#   'UkraineRussianWar',
#   'Ukraine',
#   'Biden',
#   'Kyiv',
#   'Mariupol',
#   'Nazism'],
#  ['SmartNews'],
#  ['history', 'ukraine', 'war'],
#  [],
#  ['Anonymous'],
#  ['Ukraine', 'War', 'Russia', 'SpaceX', 'ElonMusk', 'Solar', 'FLare'],
#  [],
#  ['PutinOutOfUkraine'],
#  [],
#  [],
#  [],
#  [],
#  ['RussianWarCrimes'],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  ['Marketing', 'MarketingStrategy', 'brand', 'branding'],
#  [],
#  ['RussianUkrainianWar',
#   'UkraineRussia',
#   'UkraineRussiaCrisis',
#   'RussiaUkraineWar',
#   'RussiaUkraineConflict',
#   'Simpsons',
#   'Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['RussianUkrainianWar', 'Ukraine'],
#  ['kidsOfUkraine', 'StopTheWarInUkraine'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  ['peaceinukraine'],
#  [],
#  [],
#  [],
#  ['Ukraine',
#   'UkraineWar',
#   'UkraineUnderAttack',
#   'StopWar',
#   'UkraineRussiaWar',
#   'UkraineInvasion',
#   'RussianUkrainianWar'],
#  [],
#  [],
#  ['VladimirPutin',
#   'RussianUkrainianWar',
#   'Ukraine',
#   'Russia',
#   'BoycottMcDonalds',
#   'BoycottCocaCola',
#   'boycottpapajohns'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  ['smh'],
#  ['YEMEN'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['NewsAndInformation'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  ['putinisadick'],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['parents', 'caregivers', 'Ukraine'],
#  ['dkpol', 'ZelenskyWarCriminal', 'dkmedier', 'UkraineRussianWar'],
#  [],
#  [],
#  ['Ukraine', 'Tigray', 'TigrayGenocide'],
#  [],
#  ['Putin', 'Ukraine'],
#  [],
#  ['Putinâ',
#   'war',
#   'Ukraine',
#   'legitimacy',
#   'Ukraine',
#   'UkraineWar',
#   'Russia',
#   'NATO',
#   'EU',
#   'UN',
#   'OSCE'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  ['Kyiv', 'Lviv', 'Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  ['freedom', 'Americans', 'Ukraine', 'Bidens', 'MAGA'],
#  ['UkraineRussianWar'],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  ['Putin', 'Ukraine'],
#  [],
#  [],
#  ['FreeUkraine', 'Ukraineð'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'JoeBiden', 'russianoil', 'Russia'],
#  [],
#  [],
#  [],
#  ['Ukraine'],
#  [],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  [],
#  [],
#  ['NATO', 'Racism', 'EuropeSupremacy'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['youchoose'],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666'],
#  [],
#  ['Ukraine',
#   'UkraineWar',
#   'UkraineUnderAttack',
#   'StopWar',
#   'UkraineRussiaWar',
#   'UkraineInvasion',
#   'RussianUkrainianWar'],
#  ['Putin', 'Ukraine'],
#  ['UkraineRussianWar'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Ukraine', 'Syria'],
#  [],
#  ['astrology'],
#  [],
#  [],
#  [],
#  ['PrayForUkraine',
#   'RussiaUkraine',
#   'SaveUkraine',
#   'StopPutin',
#   'russianinvasion',
#   '666']]

# %%
hashtags=sum(hashtags,[])
hashtags
# Out:
# ['Ukraine',
#  'IStandWithUkraine',
#  'sanctions',
#  'russia',
#  'WW3',
#  'Ukraine',
#  'NATO',
#  'USA',
#  'war',
#  'Politics',
#  'Russia',
#  'UkraineWar',
#  'UkraineRussianWar',
#  'Ukraine',
#  'Russia',
#  'CzarVladimir',
#  'Ukraine',
#  'StanGrant',
#  'Dutton',
#  'insiders',
#  'auspol',
#  'UkraineRussianWar',
#  'Russia',
#  'UKRAINE',
#  'Russia',
#  'WWWIII',
#  'TruckersConvoy2022',
#  'PutinWarCrimes',
#  'StopRussia',
#  'DemVoice1',
#  'Ukraine',
#  'NoWar',
#  'Stop_the_War',
#  'We_are_all_friends',
#  'Wake_up_troops',
#  'Hugs_to_all',
#  'ukraine',
#  'Ukraine',
#  'UkraineRussianWar',
#  'IStandWithUkraine',
#  'worldwar3',
#  'AzovBattalion',
#  'russia',
#  'ukraine',
#  'IStandWithPutin',
#  'NoFlyZoneOverUkraine',
#  'RussianArmy',
#  'StopEnablingPutin',
#  'Ukraine',
#  'Putin',
#  'war',
#  'WarCrimes',
#  'ukraine',
#  'StandWithUkrain',
#  'russia',
#  'NYC',
#  'UkraineRussianWar',
#  'UkraineWar',
#  'cnn',
#  'Ukraine',
#  'Russia',
#  'Ukraine',
#  'RussiaUkraineConflict',
#  'Ukraine',
#  'Russia',
#  'Ukraine',
#  'US',
#  'Iraq',
#  'Ukraine',
#  'Lybia',
#  'Syria',
#  'Afghanistan',
#  'Palestine',
#  'RussianUkrainianWar',
#  'Ukraine',
#  'StandWithUkraineï',
#  'StopPutin',
#  'SlavaUkraini',
#  'UkraineRussiaWar',
#  'Russia',
#  'UkraineUnderAttaÑ',
#  'FBPE',
#  'MiddleEast',
#  'UkraineRussianWar',
#  'CrudeOil',
#  'BREAKING',
#  'Ukraine',
#  'ClosetheSkyoverUkraine',
#  'NoFlyZone',
#  'NoFlyZoneOverUkraine',
#  'RussiaEU',
#  'Ukraine',
#  'Russia',
#  'Ukraine',
#  'Ukraine',
#  'Godspeed',
#  'Ukrania',
#  'putin',
#  'Ukraine',
#  'fuckputin',
#  'PutinWarCriminal',
#  'Ukraine',
#  'SlavaUkraini',
#  'GloryToUkraine',
#  'UkraineWar',
#  'SupportUkraine',
#  'NOBODYWANTSWAR',
#  'STOPWAR',
#  'UKRAINEWAR',
#  'WARINUKRAINE',
#  'PrayingForUkraine',
#  'Genocide',
#  'war',
#  'MaksimChmerkovskiy',
#  'Russia',
#  'Ukraine',
#  'War',
#  'USSR',
#  'ukraine',
#  'russia',
#  'putin',
#  'peace',
#  'war',
#  'digitalcollage',
#  'kyiv',
#  'ukraine',
#  'war',
#  'Western_media_racism',
#  'RussianUkrainianWar',
#  'Ø',
#  'Ukraine',
#  'ukraine',
#  'UkraineUnderAttaÑ',
#  'ColdWar',
#  'CIA',
#  'PutinWarCrimes',
#  'Ukraine',
#  'Ukraine',
#  'VladimirPutin',
#  'Russia',
#  'RT',
#  'UkraineCrises',
#  'RussiaUkraineCrisis',
#  'Ukraine',
#  'UkraineKrieg',
#  'UkraineWar',
#  'Ukraine',
#  'Russia',
#  'Ukraine',
#  'NoFlyZone',
#  'Ukraine',
#  'Putinâ',
#  'Ukraine',
#  'Putin',
#  'Russia',
#  'China',
#  'Ukraine',
#  'Russian',
#  'Chinese',
#  'sanctions',
#  'cancel',
#  'Ukraine',
#  'QueMaskOffbyFuture',
#  'Ukraineonthebrain',
#  'UkraineConflict',
#  'UkraineWar',
#  'Ukraine',
#  'NoWar',
#  'Ukraine',
#  'Russia',
#  'Ukraine',
#  'JohnsonTheRussianStooge',
#  'tory',
#  'Brexit',
#  'UkraineRussianWar',
#  'RussiaUkraine',
#  'Ukraine',
#  'Russia',
#  'UkraineWar',
#  'Russia',
#  'Ukraine',
#  'UkraineRussianWar',
#  'war',
#  'Ukraine',
#  'Putin',
#  'sanctions',
#  'Russia',
#  'noflyzone',
#  'Ukraine',
#  'Ukraine',
#  'Ukraine',
#  'Ukraine',
#  'Ukraine',
#  'Russia',
#  'War',
#  'WarCrimes',
#  'WARINUKRAINE',
#  'Border',
#  'Ukraine',
#  'Russia',
#  'InvasionUcrania',
#  'daytrading',
#  'stocks',
#  'stockmarket',
#  'Business',
#  'business',
#  'Propaganda',
#  'RussiaUkraineWar',
#  'Russia',
#  'Putin',
#  'Ukraine',
#  'information',
#  'publicity',
#  'war',
#  'propagandawars',
#  'Putinâ',
#  'Ukraine',
#  'UkraineRussiaWar',
#  'Ukraine',
#  'StandWithUkraine',
#  'stopwar',
#  'stoprussia',
#  'ukraine',
#  'lettherebepeace',
#  'cancelputin',
#  'Ukraine',
#  'SupportUkraine',
#  'HelpUkraine',
#  'Ukrainians',
#  'Russians',
#  'FreeUkraine',
#  'UkraineWar',
#  'PutinWarCriminal',
#  'PutinWarCrimes',
#  'Putin',
#  'killPutin',
#  'Putitler',
#  'Ukraine',
#  'Russia',
#  'war',
#  'London',
#  'TrafalgarSquare',
#  'playforukraine',
#  'Ukraine',
#  'RussianUkrainianWar',
#  'Russia',
#  'Russia',
#  'stopwar',
#  'stoprussia',
#  'ukraine',
#  'lettherebepeace',
#  'cancelputin',
#  'ThankYouJournalistsForTheNewsWeGetFromYou',
#  'AndyVermautThanksYou',
#  'news',
#  'topstories',
#  'berkleybearnews',
#  'Ukraine',
#  'Russia',
#  'PutinWarCriminal',
#  'Genocide',
#  'istandwithrussia',
#  'RussianUkrainianWar',
#  'Putin',
#  'Ukraine',
#  'NoFlyZoneOverUkraine',
#  'Putin',
#  'Ukraine',
#  'stopwar',
#  'stoprussia',
#  'ukraine',
#  'lettherebepeace',
#  'cancelputin',
#  'Ukraine',
#  'GOPtheRussianParty',
#  'Putin',
#  'Ukraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'meidastouch',
#  'Rubio',
#  'Ukraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'UkraineRussianWar',
#  'Russia',
#  'Ukraine',
#  'UkraineArmy',
#  'UkraineConflict',
#  'UkraineWar',
#  'UkraineCrisis',
#  'WARINUKRAINE',
#  'CloseTheSkyUkraine',
#  'Ukraine',
#  'Washington',
#  'nytimes',
#  'nato',
#  'eu',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'prayforukraine',
#  'ukraine',
#  'peaceforukraine',
#  'NFT',
#  'Ukraine',
#  'Biafra',
#  'Biafra',
#  'FreeMaziNnamdiKanuNow',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'Russia',
#  'UkraineRussia',
#  'RussiaUkraine',
#  'RussiaUkraineWar',
#  'rusiaukraina',
#  'UkraineRussianWar',
#  'UkraineRussiaWar',
#  'UkraineWar',
#  'Ukraine',
#  'Russie',
#  'Peace',
#  'war',
#  'Ukraine',
#  'Russia',
#  'Kyiv',
#  'StandWithUkraine',
#  'BigAg',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'MAGA',
#  'Trump',
#  'Republican',
#  'Jan6th',
#  'Ukraine',
#  'Russia',
#  'Ukraine',
#  'anime',
#  'movie',
#  'Russians',
#  'Stop',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'Ukraine',
#  'Russie',
#  'war',
#  'Peace',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'ukraine',
#  'Ukraine',
#  'SundayMorning',
#  'SlavaUkraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'UkraineRussiaWar',
#  'UkraineKrieg',
#  'UkraineUnderAttack',
#  'UkraineWar',
#  'UkraineInvasion',
#  'UkraineRussie',
#  'UkraineRussiaCrisis',
#  'SaveUkraine',
#  'drones',
#  'spying',
#  'NATO',
#  'Putin',
#  'Ukraine',
#  'PutinsWar',
#  'cdnpoli',
#  'Ukraine',
#  'PutinWarCrimes',
#  'putinpuppet',
#  'Putins',
#  'Ukraine',
#  'Russie',
#  'Kharkiv',
#  'UkraineRussianWar',
#  'Poutine',
#  'UkraineWar',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'UkraineRussianWar',
#  'Ukraine',
#  'USA',
#  'EU',
#  'UK',
#  'NATO',
#  'Boycott',
#  'ukrainewar',
#  'UkraineRussiaWar',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Luhansk',
#  'Zaporizhzhia',
#  'Ukraine',
#  'Russia',
#  'UkraineWar',
#  'Bitcoin',
#  'Ukraine',
#  'Russia',
#  'cryptocurrency',
#  'CryptoCurrencies',
#  'Bitcoin',
#  'Ethereum',
#  'NFT',
#  'NFTs',
#  'NFTCommunity',
#  'OtherEconomy',
#  'OtraEconomia',
#  'Metaverse',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'Lviv',
#  'Ukraine',
#  'RussianAggression',
#  'Economy',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Putin',
#  'Ukraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'UkraineRussianWar',
#  'UkraineWar',
#  'UkraineUnderAttaÑ',
#  'Ukraine',
#  'UkraineRussia',
#  'Ukraina',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Stop',
#  'ukrainewar',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'AfricansinUkraine',
#  'VOA',
#  'Putin',
#  'UkraineRussianWar',
#  'Ukraine',
#  'Biden',
#  'Kyiv',
#  'Mariupol',
#  'Nazism',
#  'SmartNews',
#  'history',
#  'ukraine',
#  'war',
#  'Anonymous',
#  'Ukraine',
#  'War',
#  'Russia',
#  'SpaceX',
#  'ElonMusk',
#  'Solar',
#  'FLare',
#  'PutinOutOfUkraine',
#  'RussianWarCrimes',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Marketing',
#  'MarketingStrategy',
#  'brand',
#  'branding',
#  'RussianUkrainianWar',
#  'UkraineRussia',
#  'UkraineRussiaCrisis',
#  'RussiaUkraineWar',
#  'RussiaUkraineConflict',
#  'Simpsons',
#  'Ukraine',
#  'RussianUkrainianWar',
#  'Ukraine',
#  'kidsOfUkraine',
#  'StopTheWarInUkraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'peaceinukraine',
#  'Ukraine',
#  'UkraineWar',
#  'UkraineUnderAttack',
#  'StopWar',
#  'UkraineRussiaWar',
#  'UkraineInvasion',
#  'RussianUkrainianWar',
#  'VladimirPutin',
#  'RussianUkrainianWar',
#  'Ukraine',
#  'Russia',
#  'BoycottMcDonalds',
#  'BoycottCocaCola',
#  'boycottpapajohns',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'smh',
#  'YEMEN',
#  'NewsAndInformation',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'putinisadick',
#  'Ukraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'parents',
#  'caregivers',
#  'Ukraine',
#  'dkpol',
#  'ZelenskyWarCriminal',
#  'dkmedier',
#  'UkraineRussianWar',
#  'Ukraine',
#  'Tigray',
#  'TigrayGenocide',
#  'Putin',
#  'Ukraine',
#  'Putinâ',
#  'war',
#  'Ukraine',
#  'legitimacy',
#  'Ukraine',
#  'UkraineWar',
#  'Russia',
#  'NATO',
#  'EU',
#  'UN',
#  'OSCE',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'Kyiv',
#  'Lviv',
#  'Ukraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'freedom',
#  'Americans',
#  'Ukraine',
#  'Bidens',
#  'MAGA',
#  'UkraineRussianWar',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Putin',
#  'Ukraine',
#  'FreeUkraine',
#  'Ukraineð',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'JoeBiden',
#  'russianoil',
#  'Russia',
#  'Ukraine',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'NATO',
#  'Racism',
#  'EuropeSupremacy',
#  'youchoose',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666',
#  'Ukraine',
#  'UkraineWar',
#  'UkraineUnderAttack',
#  'StopWar',
#  'UkraineRussiaWar',
#  'UkraineInvasion',
#  'RussianUkrainianWar',
#  'Putin',
#  'Ukraine',
#  'UkraineRussianWar',
#  'Ukraine',
#  'Syria',
#  'astrology',
#  'PrayForUkraine',
#  'RussiaUkraine',
#  'SaveUkraine',
#  'StopPutin',
#  'russianinvasion',
#  '666']

# %%
hash=hashtag_freq(hashtags)
hash
# Out:
#                   Hashtag  Freq
# 0                 Ukraine    98
# 9                  Russia    33
# 99          RussiaUkraine    32
# 49              StopPutin    31
# 135           SaveUkraine    31
# 134        PrayForUkraine    30
# 136       russianinvasion    30
# 137                   666    30
# 10             UkraineWar    16
# 11      UkraineRussianWar    16
# 35                  Putin    14
# 7                     war    12
# 28                ukraine    12
# 47    RussianUkrainianWar     9
# 51       UkraineRussiaWar     7
# 5                    NATO     5
# 3                  russia     4
# 20         PutinWarCrimes     4
# 2               sanctions     3
# 32   NoFlyZoneOverUkraine     3
# 52      UkraineUnderAttaÑ     3
# 64       PutinWarCriminal     3
# 70           WARINUKRAINE     3
# 74                    War     3
# 88                 Putinâ     3
# 109      RussiaUkraineWar     3
# 114               stopwar     3
# 115            stoprussia     3
# 116       lettherebepeace     3
# 117           cancelputin     3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(26,7))
ax=sns.barplot(data=hash, x='Hashtag', y="Freq")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# now , we analyse the tweets part:

# %%
data['total_length']=data['content'].str.len()

# %%
data[['content','total_length']]
# Out:
#                                                content  total_length
# 0    There was an anti war protest for #Ukraine as ...           326
# 1    https://t.co/Z1pURKlNHu NATO followed USA into...           280
# 2    @mfa_russia @RusEmbUSA @RussiaUN @MFA_Ukraine ...           348
# 3    @nytimes This war could have been avoided by e...            95
# 4    @ggreenwald Remember the biggest mistake made ...           260
# ..                                                 ...           ...
# 734  What the War in Ukraine Means for the Worldâ...           199
# 735  @escapeartistes Hmmm havenât seen those. But...           206
# 736  I fully expect NATO leaders and the Ukraine mi...           203
# 737  @NewGuyUserName1 @NovElection2024 He does when...           135
# 738  Russia VS Ukraine War. It's horrible. I made a...           279
#
# [739 rows x 2 columns]

# %%
total_len=data['total_length'].sum()
total_len
# Out:
# 156296

# %%
avg_tweet_len=total_len/len(data['content'])
avg_tweet_len
# Out:
# 211.49661705006767

# %%
data['word_count']=data['content'].str.split().str.len()

# %%
data[['content','total_length','word_count']]
# Out:
#                                                content  total_length  \
# 0    There was an anti war protest for #Ukraine as ...           326
# 1    https://t.co/Z1pURKlNHu NATO followed USA into...           280
# 2    @mfa_russia @RusEmbUSA @RussiaUN @MFA_Ukraine ...           348
# 3    @nytimes This war could have been avoided by e...            95
# 4    @ggreenwald Remember the biggest mistake made ...           260
# ..                                                 ...           ...
# 734  What the War in Ukraine Means for the Worldâ...           199
# 735  @escapeartistes Hmmm havenât seen those. But...           206
# 736  I fully expect NATO leaders and the Ukraine mi...           203
# 737  @NewGuyUserName1 @NovElection2024 He does when...           135
# 738  Russia VS Ukraine War. It's horrible. I made a...           279
#
#      word_count
# 0            44
# 1            39
# 2            40
# 3            17
# 4            42
# ..          ...
# 734          30
# 735          34
# 736          38
# 737          22
# 738          40
#
# [739 rows x 3 columns]

# %%
avg_word_count=data['word_count'].sum()/len(data['content'])
avg_word_count
# Out:
# 32.895805142083894

# %% [markdown]
# # sentiment analysis

# %%
import string

# %%
text=data['content'][100]
text
# Out:
# '1) go to maps\n\n2) find a Russian city (like Moscow)\n\n3) find a restaurant, cafe or bar\n\n4) write a review but write about the war in #Ukraine \n\n5) post it\n\n#StandWithUkraineï¸\x8f #StopPutin #SlavaUkraini #UkraineRussiaWar #Russia #UkraineUnderAttaÑ\x81k #FBPE https://t.co/TEkreF6Q0a'

# %%
text=str(text).lower()
text=re.sub('https?://\S+|www\.\S+','',text)


text
# Out:
# '1) go to maps\n\n2) find a russian city (like moscow)\n\n3) find a restaurant, cafe or bar\n\n4) write a review but write about the war in #ukraine \n\n5) post it\n\n#standwithukraineï¸\x8f #stopputin #slavaukraini #ukrainerussiawar #russia #ukraineunderattañ\x81k #fbpe '

# %%
text=re.sub('[%s]'%re.escape(string.punctuation),'',text)
text
# Out:
# '1 go to maps\n\n2 find a russian city like moscow\n\n3 find a restaurant cafe or bar\n\n4 write a review but write about the war in ukraine \n\n5 post it\n\nstandwithukraineï¸\x8f stopputin slavaukraini ukrainerussiawar russia ukraineunderattañ\x81k fbpe '

# %%
text=re.sub('\n|\t','',text)
text
# Out:
# '1 go to maps2 find a russian city like moscow3 find a restaurant cafe or bar4 write a review but write about the war in ukraine 5 post itstandwithukraineï¸\x8f stopputin slavaukraini ukrainerussiawar russia ukraineunderattañ\x81k fbpe '

# %%
text=re.sub('\d','',text)
text
# Out:
# ' go to maps find a russian city like moscow find a restaurant cafe or bar write a review but write about the war in ukraine  post itstandwithukraineï¸\x8f stopputin slavaukraini ukrainerussiawar russia ukraineunderattañ\x81k fbpe '

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
stopword=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(len(stopword))
stopword=set(stopword)
len(stopword)
# Out:
# 179
# 179

# %%
text
# Out:
# ' go to maps find a russian city like moscow find a restaurant cafe or bar write a review but write about the war in ukraine  post itstandwithukraineï¸\x8f stopputin slavaukraini ukrainerussiawar russia ukraineunderattañ\x81k fbpe '

# %%
text=[word for word in text.split(' ') if word not in stopword]
text
# Out:
# ['',
#  'go',
#  'maps',
#  'find',
#  'russian',
#  'city',
#  'like',
#  'moscow',
#  'find',
#  'restaurant',
#  'cafe',
#  'bar',
#  'write',
#  'review',
#  'write',
#  'war',
#  'ukraine',
#  '',
#  'post',
#  'itstandwithukraineï¸\x8f',
#  'stopputin',
#  'slavaukraini',
#  'ukrainerussiawar',
#  'russia',
#  'ukraineunderattañ\x81k',
#  'fbpe',
#  '']

# %%
text=" ".join(text)
text
# Out:
# ' go maps find russian city like moscow find restaurant cafe bar write review write war ukraine  post itstandwithukraineï¸\x8f stopputin slavaukraini ukrainerussiawar russia ukraineunderattañ\x81k fbpe '

# %%
stemmer=nltk.SnowballStemmer('english')

# %%
text=[stemmer.stem(word) for word in text.split(' ')]
text
# Out:
# ['',
#  'go',
#  'map',
#  'find',
#  'russian',
#  'citi',
#  'like',
#  'moscow',
#  'find',
#  'restaur',
#  'cafe',
#  'bar',
#  'write',
#  'review',
#  'write',
#  'war',
#  'ukrain',
#  '',
#  'post',
#  'itstandwithukraineï¸\x8f',
#  'stopputin',
#  'slavaukraini',
#  'ukrainerussiawar',
#  'russia',
#  'ukraineunderattañ\x81k',
#  'fbpe',
#  '']

# %%
text=" ".join(text)
text
# Out:
# ' go map find russian citi like moscow find restaur cafe bar write review write war ukrain  post itstandwithukraineï¸\x8f stopputin slavaukraini ukrainerussiawar russia ukraineunderattañ\x81k fbpe '

# %%
def clean(text):
  text=str(text).lower()
  text=re.sub('https?://\S+|www\.\S+','',text)
  text=re.sub('[%s]'%re.escape(string.punctuation),'',text)
  text=re.sub('\n|\t','',text)
  text=re.sub('\d','',text)
  text=[word for word in text.split(' ') if word not in stopword]
  text=" ".join(text)
  text=[stemmer.stem(word) for word in text.split(' ')]
  text=" ".join(text)

  return text

# %%
data['clear_tweet']=data['content'].apply(clean)

# %%
data[['clear_tweet','content']]
# Out:
#                                            clear_tweet  \
# 0    anti war protest ukrain well itâ get headlin...
# 1     nato follow usa afghanistan forgotten alreadi...
# 2    mfarussia rusembusa russiaun mfaukrain natomis...
# 3    nytim war could avoid ensur putin ukrain could...
# 4    ggreenwald rememb biggest mistak made support ...
# ..                                                 ...
# 734  war ukrain mean worldâ food suppli   remind ...
# 735  escapeartist hmmm havenât seen unless itâ ...
# 736  fulli expect nato leader ukrain mitari review ...
# 737  newguyusernam novelect cancel keyston pipelin ...
# 738  russia vs ukrain war horribl made discord serv...
#
#                                                content
# 0    There was an anti war protest for #Ukraine as ...
# 1    https://t.co/Z1pURKlNHu NATO followed USA into...
# 2    @mfa_russia @RusEmbUSA @RussiaUN @MFA_Ukraine ...
# 3    @nytimes This war could have been avoided by e...
# 4    @ggreenwald Remember the biggest mistake made ...
# ..                                                 ...
# 734  What the War in Ukraine Means for the Worldâ...
# 735  @escapeartistes Hmmm havenât seen those. But...
# 736  I fully expect NATO leaders and the Ukraine mi...
# 737  @NewGuyUserName1 @NovElection2024 He does when...
# 738  Russia VS Ukraine War. It's horrible. I made a...
#
# [739 rows x 2 columns]

# %%
avg_len_after_clean=data['clear_tweet'].str.len().sum()/len(data['content'])
avg_len_after_clean
# Out:
# 128.8403247631935

# %%
avg_word_count_after_clean=data['clear_tweet'].str.split().str.len().sum()/len(data['content'])
avg_word_count_after_clean
# Out:
# 19.055480378890394

# %%
from textblob import TextBlob

# %%
text=data['clear_tweet'][1]
text
# Out:
# ' nato follow usa afghanistan forgotten alreadi tribe western journalist hope biden bemoan us loss afghan alli forgotten headlin ukrain war anoth syria come  west arm insurg destabilis'

# %%
anlysis=TextBlob(data['clear_tweet'][14])
anlysis.sentiment.polarity
# Out:
# -0.2

# %%
def sen_analysis(text):
  anlysis=TextBlob(text)
  if anlysis.sentiment.polarity > 0:
    return 1
  elif anlysis.sentiment.polarity ==0:
    return 0
  else:
    return -1

# %%
data['sentiment']=data['clear_tweet'].apply(lambda x:sen_analysis(x))

# %%
data[['clear_tweet','sentiment']]
# Out:
#                                            clear_tweet  sentiment
# 0    anti war protest ukrain well itâ get headlin...          1
# 1     nato follow usa afghanistan forgotten alreadi...          0
# 2    mfarussia rusembusa russiaun mfaukrain natomis...         -1
# 3    nytim war could avoid ensur putin ukrain could...          0
# 4    ggreenwald rememb biggest mistak made support ...          0
# ..                                                 ...        ...
# 734  war ukrain mean worldâ food suppli   remind ...         -1
# 735  escapeartist hmmm havenât seen unless itâ ...          0
# 736  fulli expect nato leader ukrain mitari review ...          1
# 737  newguyusernam novelect cancel keyston pipelin ...         -1
# 738  russia vs ukrain war horribl made discord serv...          0
#
# [739 rows x 2 columns]

# %%
data['retweetCount']
# Out:
# 0      4
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 734    1
# 735    0
# 736    0
# 737    0
# 738    0
# Name: retweetCount, Length: 739, dtype: int64

# %%
data['len_clean_text']=data['clear_tweet'].apply(len)
data['wordcount_clean_text']=data['clear_tweet'].apply(lambda x: len(str(x).split()))

# %%
data1=data[['clear_tweet','sentiment', 'retweetCount', 'len_clean_text', 'wordcount_clean_text']]
data1
# Out:
#                                            clear_tweet  sentiment  \
# 0    anti war protest ukrain well itâ get headlin...          1
# 1     nato follow usa afghanistan forgotten alreadi...          0
# 2    mfarussia rusembusa russiaun mfaukrain natomis...         -1
# 3    nytim war could avoid ensur putin ukrain could...          0
# 4    ggreenwald rememb biggest mistak made support ...          0
# ..                                                 ...        ...
# 734  war ukrain mean worldâ food suppli   remind ...         -1
# 735  escapeartist hmmm havenât seen unless itâ ...          0
# 736  fulli expect nato leader ukrain mitari review ...          1
# 737  newguyusernam novelect cancel keyston pipelin ...         -1
# 738  russia vs ukrain war horribl made discord serv...          0
#
#      retweetCount  len_clean_text  wordcount_clean_text
# 0               4             162                    23
# 1               0             183                    27
# 2               0             250                    26
# 3               0              56                    10
# 4               0             160                    22
# ..            ...             ...                   ...
# 734             1              96                    15
# 735             0             142                    21
# 736             0             122                    20
# 737             0              74                    11
# 738             0             173                    24
#
# [739 rows x 5 columns]

# %%
sentiment=data1['sentiment'].value_counts()
sentiment
# Out:
#  0    366
#  1    213
# -1    160
# Name: sentiment, dtype: int64

# %%
sns.countplot(data=data1, x='sentiment')

# %%
negative=data1[data1['sentiment']==-1]
neutral=data1[data1['sentiment']==0]
positive=data1[data1['sentiment']==1]

# %%
positive.iloc[36]
# Out:
# clear_tweet             tammyrendl mirismail cnnbrk peopl kill right s...
# sentiment                                                               1
# retweetCount                                                            0
# len_clean_text                                                        211
# wordcount_clean_text                                                   32
# Name: 122, dtype: object

# %%
text=' '.join(text for text in data1['clear_tweet'])

# %%
len(text)
# Out:
# 95951

# %%
from wordcloud import WordCloud

# %%
wordcloud=WordCloud(max_font_size=100,
                    max_words=50).generate(text)

plt.imshow(wordcloud, interpolation= 'bilinear')
plt.show()

# %%
positive
# Out:
#                                            clear_tweet  sentiment  \
# 0    anti war protest ukrain well itâ get headlin...          1
# 6    sanction truli recordbreak cours neededbut hug...          1
# 7    hope edward snowden ok manag leav russiaukrain...          1
# 8    sharmasupriya nanditada didnât indian admini...          1
# 11   internecin war ukrain true arm forc azov nazis...          1
# ..                                                 ...        ...
# 724  apcbyeby reuter think russia abil make war lik...          1
# 726  seakamelaphd costerrama time putin provoc one ...          1
# 729  jradrabel logist poor donât think take ukrai...          1
# 731  group russian prison war parad press ukrainepr...          1
# 736  fulli expect nato leader ukrain mitari review ...          1
#
#      retweetCount  len_clean_text  wordcount_clean_text
# 0               4             162                    23
# 6               0             141                    19
# 7               0              50                     7
# 8               0             140                    21
# 11              2             137                    20
# ..            ...             ...                   ...
# 724             1             116                    18
# 726             0             201                    31
# 729             0             154                    24
# 731             1             143                    20
# 736             0             122                    20
#
# [213 rows x 5 columns]

# %%
text=' '.join(text for text in positive['clear_tweet'])

# %%
len(text)
# Out:
# 30192

# %%
wordcloud=WordCloud(max_font_size=100,
                    max_words=50).generate(text)

plt.imshow(wordcloud, interpolation= 'bilinear')
plt.show()
